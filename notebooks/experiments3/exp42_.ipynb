# %%
import json
import os
import sys

import joblib

# Добавляем корневую директорию проекта в sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))

# Импортируем metrics из utils
from utils import metrics as mtc
from utils import preprocess_functions as ppf
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\filat\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\filat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Готовим дата-сеты (предобработка)

# %%
reference = pd.read_csv("../../data/preprocessed/general/reference.csv")
train = pd.read_csv("../../data/splited/train.csv")
valid = pd.read_csv("../../data/splited/valid.csv")

abbr_dict = joblib.load("../../resources/general/abbreviations_dict.joblib")
region_dict = joblib.load("../../resources/general/region_dict.joblib")
blacklist_opf = joblib.load("../../resources/general/blacklist_opf.joblib")

# %%
reference["processed_name"] = reference.name.apply(
    ppf.simple_preprocess_text
).str.lower()
reference.processed_name = reference.processed_name.apply(ppf.replace_numbers_with_text)
reference.processed_name = reference.processed_name.apply(
    ppf.abbr_preprocess_text, args=(abbr_dict, False, False, True, False)
)
reference.processed_name = reference.processed_name.apply(
    ppf.process_region, args=(list(region_dict.keys()),)
)
reference.processed_name = reference.processed_name.apply(
    ppf.remove_substrings, args=(blacklist_opf,)
)
reference["processed_name"] = reference.processed_name.apply(ppf.simple_preprocess_text)
reference.head(1)
# Out:
#    id      name              region processed_name
# 0  69  Кировска  мурманская область       кировска

# %%
train["processed_name"] = train.name.apply(ppf.simple_preprocess_text).str.lower()
train.processed_name = train.processed_name.apply(ppf.replace_numbers_with_text)
train.processed_name = train.processed_name.apply(
    ppf.abbr_preprocess_text, args=(abbr_dict, False, False, True, False)
)
train["region"] = train.processed_name.apply(
    ppf.process_region, args=(list(region_dict.keys()), True)
)
train.processed_name = train.processed_name.apply(
    ppf.process_region, args=(list(region_dict.keys()),)
)
train.processed_name = train.processed_name.apply(
    ppf.remove_substrings, args=(blacklist_opf,)
)
train["processed_name"] = train.processed_name.apply(ppf.simple_preprocess_text)
train.head(1)
# Out:
#                       name  school_id           processed_name  \
# 0  ХМАО-Югра, СШ г. Покачи        173  спортивная школа покачи
#
#                               region
# 0  ханты мансийский автономный округ

# %%
valid["processed_name"] = valid.name.apply(ppf.simple_preprocess_text).str.lower()
valid.processed_name = valid.processed_name.apply(ppf.replace_numbers_with_text)
valid.processed_name = valid.processed_name.apply(
    ppf.abbr_preprocess_text, args=(abbr_dict, False, False, True, False)
)
valid["region"] = valid.processed_name.apply(
    ppf.process_region, args=(list(region_dict.keys()), True)
)

valid.processed_name = valid.processed_name.apply(
    ppf.process_region, args=(list(region_dict.keys()),)
)
valid.processed_name = valid.processed_name.apply(
    ppf.remove_substrings, args=(blacklist_opf,)
)
valid["processed_name"] = valid.processed_name.apply(ppf.simple_preprocess_text)
valid.head(1)
# Out:
#                  name  school_id                      processed_name region
# 0  КФК Е. Герасимовой       1843  клуб фигурного катания герасимовой   None

# %% [markdown]
# ### Преобразования в np.array

# %%
x_train = train["processed_name"].to_numpy(dtype="str").flatten()
y_train = train["school_id"].to_numpy(dtype="int").flatten()
region_train = train["region"].to_numpy(dtype="str").flatten()

x_valid = valid["processed_name"].to_numpy(dtype="str").flatten()
y_valid = valid["school_id"].to_numpy(dtype="int").flatten()
region_valid = valid["region"].to_numpy(dtype="str").flatten()

reference_id = reference["id"].to_numpy(dtype="int").flatten()
reference_name = reference["processed_name"].to_numpy(dtype="str").flatten()
reference_region = reference["region"].to_numpy(dtype="str").flatten()

# %%
joblib.dump(reference_id, "../../resources/exp42/reference_id.joblib")
joblib.dump(reference_name, "../../resources/exp42/reference_name.joblib")
joblib.dump(reference_region, "../../resources/exp42/reference_region.joblib")
# Out:
# ['../../resources/exp42/reference_region.joblib']

# %% [markdown]
# # Модель

# %%
from sklearn.metrics.pairwise import euclidean_distances, manhattan_distances


def calculate_similarity(x, y, method="cosine"):
    if method == "cosine":
        return cosine_similarity(x, y)
    elif method == "euclidean":
        return -euclidean_distances(x, y)  # Инвертируем, чтобы максимизировать схожесть
    elif method == "manhattan":
        return -manhattan_distances(x, y)  # Инвертируем, чтобы максимизировать схожесть
    else:
        raise ValueError(f"Unknown similarity method: {method}")


def find_matches(
    x_vec,
    x_region,
    reference_id,
    reference_vec,
    reference_region,
    top_k=5,
    threshold=0.9,
    filter_by_region=True,
    empty_region="all",
    similarity_method="cosine",
):
    y_pred = []
    manual_review = []

    for i, x in enumerate(x_vec):
        # Фильтруем reference_vec и reference_id по текущему региону, если включена фильтрация по регионам
        if filter_by_region:
            # Фильтруем reference_vec и reference_id по текущему региону
            current_region = x_region[i]
            region_mask = reference_region == current_region
            filtered_reference_vec = reference_vec[region_mask]
            filtered_reference_id = reference_id[region_mask]

            # Способ обработки, если в текущем регионе нет школ для сравнения
            if empty_region == "all":
                # Если в текущем регионе нет школ для сравнения, используем все школы
                if filtered_reference_vec.shape[0] == 0:
                    filtered_reference_vec = reference_vec
                    filtered_reference_id = reference_id
            else:
                if filtered_reference_vec.shape[0] == 0:
                    # Если в текущем регионе нет школ для сравнения, то помечаем на ручную обработку
                    manual_review.append(x)
                    top_matches = [(None, 0.0)] * top_k
                    y_pred.append(top_matches)
                    continue
        else:
            filtered_reference_vec = reference_vec
            filtered_reference_id = reference_id

        # Вычисляем выбранное расстояние
        similarities = calculate_similarity(
            x, filtered_reference_vec, method=similarity_method
        ).flatten()
        top_indices = similarities.argsort()[-top_k:][::-1]
        max_similarity = max(similarities)

        # Учитываем пороговое значение для различных методов
        if similarity_method == "cosine":
            if max_similarity < threshold:
                manual_review.append(x)
                top_matches = [(None, 0.0)] * top_k
            else:
                top_matches = [
                    (filtered_reference_id[i], similarities[i]) for i in top_indices
                ]
                if len(top_matches) < top_k:
                    top_matches += [(None, 0.0)] * (top_k - len(top_matches))
        else:  # Для других методов расстояний (евклидово и манхэттенское)
            if max_similarity > -threshold:  # Обратите внимание на инверсию
                manual_review.append(x)
                top_matches = [(None, 0.0)] * top_k
            else:
                top_matches = [
                    (filtered_reference_id[i], -similarities[i]) for i in top_indices
                ]
                if len(top_matches) < top_k:
                    top_matches += [(None, 0.0)] * (top_k - len(top_matches))

        y_pred.append(top_matches)

    return y_pred, manual_review

# %% [markdown]
# # Векторизация

# %%
# Векторизация текстов
vectorizer = TfidfVectorizer().fit(np.append(x_train, reference_name))

reference_vec = vectorizer.transform(reference_name)
x_vec_valid = vectorizer.transform(x_valid)

# %%
joblib.dump(reference_vec, "../../resources/exp42/reference_vec.joblib")
joblib.dump(vectorizer, "../../resources/exp42/vectorizer.joblib")
# Out:
# ['../../resources/exp42/vectorizer.joblib']

# %%
# Массив значений threshold
threshold_values = np.linspace(0, 1.0, 25)

# Запуск функции и сбор метрик
metrics_list = []
for threshold in threshold_values:
    y_pred, manual_review = find_matches(
        x_vec_valid,
        region_valid,
        reference_id,
        reference_vec,
        reference_region,
        top_k=5,
        threshold=threshold,
        filter_by_region=True,
        empty_region="all",
        # similarity_method="euclidean",
        similarity_method="cosine",
        # similarity_method="manhattan",
    )
    metrics = mtc.calculate_metrics(y_valid, y_pred, manual_review)
    metrics_list.append(metrics)

# Преобразование метрик в удобный формат для построения графика
auto_error_rate_values = [metrics["auto_error_rate"] for metrics in metrics_list]
manual_processing_rate_values = [
    metrics["manual_processing_rate"] for metrics in metrics_list
]
# general_spend_values = [metrics['general_spend'] for metrics in metrics_list]
general_error_values = [metrics["general_error"] for metrics in metrics_list]

# %%
plots_json = {
    "threshold_values": threshold_values.tolist(),
    "auto_error_rate_values": auto_error_rate_values,
    "manual_processing_rate_values": manual_processing_rate_values,
    "general_error_values": general_error_values,
}

# Сохраняем словарь в файл JSON
with open("../../plots/exp42.json", "w", encoding="utf-8") as f:
    json.dump(plots_json, f, ensure_ascii=False, indent=4)

# %%
from matplotlib.ticker import PercentFormatter

# Построение графика
plt.figure(figsize=(8, 5))

# plt.subplot(1, 2, 1)
plt.plot(
    manual_processing_rate_values,
    auto_error_rate_values,
    label="Ошибка автоматического разбора",
)
plt.plot(manual_processing_rate_values, general_error_values, label="Общая ошибка")
plt.xlabel("Доля ручного разбора")
plt.ylabel("Ошибка")
plt.title("Зависимости ошибки")
plt.legend()

# Установка формата осей в процентах
plt.gca().xaxis.set_major_formatter(PercentFormatter(1))
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))

# Установка максимального значения оси y
plt.ylim(0, 1.0)

plt.show()

# %%
y_pred, manual_review = find_matches(
    x_vec_valid,
    region_valid,
    reference_id,
    reference_vec,
    reference_region,
    top_k=5,
    threshold=-1,
    filter_by_region=True,
    empty_region="all",  # is ignored if filter_by_region=False
    # similarity_method="euclidean",
    similarity_method="cosine",
    # similarity_method="manhattan",
)

metrics = mtc.calculate_metrics(y_valid, y_pred, manual_review)

# Сохраняем словарь в файл JSON
with open("../../evaluations/exp42.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=4)

metrics
# Out:
# {'Accuracy@1': 0.89,
#  'Accuracy@3': 1.0,
#  'Accuracy@5': 1.0,
#  'Accuracy@10': 1.0,
#  'auto_error_rate': 0.11,
#  'manual_processing_rate': 0.0,
#  'general_error': 0.11}

# %%
for i, pred in enumerate(y_pred):
    if pred[0][0] != y_valid[i]:
        print(f"Запись {i} - НЕВЕРНО")
    else:
        print(f"Запись {i}")
    print(f"--> Запрос: {x_valid[i]}, регион: {region_valid[i]}")
    print(
        f"--> Расстояние от второго до первого: {round((pred[0][1] - pred[1][1])/pred[0][1], 2)}, "
        f"разность первого и второго: {round(pred[0][1] - pred[1][1], 2)}"
    )
    print(f"--> Верный id: {y_valid[i]}")
    print("--> Варианты модели:")
    for candidate in pred:
        candidate_name = reference_name[np.where(reference_id == candidate[0])[0]]
        print(
            f"    --> {candidate[0]}, вероятность {round(candidate[1], 2)}, имя: {candidate_name}"
        )
    print()
# Out:
# Запись 0
# --> Запрос: клуб фигурного катания герасимовой, регион: None
# --> Расстояние от второго до первого: 0.61, разность первого и второго: 0.61
# --> Верный id: 1843
# --> Варианты модели:
#     --> 1843, вероятность 1.0, имя: ['клуб фигурного катания герасимовой']
#     --> 277, вероятность 0.39, имя: ['клуб фигурного катания динамо']
#     --> 611, вероятность 0.37, имя: ['клуб фигурного катания айсберг']
#     --> 236, вероятность 0.37, имя: ['федерация фигурного катания спортивный клуб']
#     --> 292, вероятность 0.36, имя: ['школа фигурного катания']
#
# Запись 1 - НЕВЕРНО
# --> Запрос: московская академия фигурного катания на коньках школа хрустальный, регион: москва
# --> Расстояние от второго до первого: 0.33, разность первого и второго: 0.27
# --> Верный id: 244
# --> Варианты модели:
#     --> 96, вероятность 0.82, имя: ['московская академия фигурного катания на коньках']
#     --> 244, вероятность 0.55, имя: ['хрустальный']
#     --> 10, вероятность 0.43, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.19, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 2
# --> Запрос: спортивный клуб фигурного катания золотой конек, регион: None
# --> Расстояние от второго до первого: 0.44, разность первого и второго: 0.36
# --> Верный id: 63
# --> Варианты модели:
#     --> 63, вероятность 0.83, имя: ['золотой конек']
#     --> 236, вероятность 0.46, имя: ['федерация фигурного катания спортивный клуб']
#     --> 36, вероятность 0.46, имя: ['спортивный клуб']
#     --> 245, вероятность 0.42, имя: ['хрустальный конек']
#     --> 105, вероятность 0.4, имя: ['спортивный клуб фигурного катания москвиной']
#
# Запись 3
# --> Запрос: спортивная школа айсберг, регион: рязанская область
# --> Расстояние от второго до первого: 0.82, разность первого и второго: 0.75
# --> Верный id: 7
# --> Варианты модели:
#     --> 7, вероятность 0.9, имя: ['айсберг']
#     --> 217, вероятность 0.16, имя: ['спортивная школа олимпийского резерва шесть']
#     --> 300, вероятность 0.0, имя: ['хоккейный клуб рязань воздушно десантные войска']
#     --> 124, вероятность 0.0, имя: ['олимпийский']
#     --> None, вероятность 0.0, имя: []
#
# Запись 4
# --> Запрос: кировское спортивная школа дымка, регион: None
# --> Расстояние от второго до первого: 0.57, разность первого и второго: 0.37
# --> Верный id: 50
# --> Варианты модели:
#     --> 50, вероятность 0.64, имя: ['дымка']
#     --> 173, вероятность 0.28, имя: ['спортивная школа']
#     --> 100, вероятность 0.28, имя: ['спортивная школа']
#     --> 1841, вероятность 0.28, имя: ['спортивная школа']
#     --> 182, вероятность 0.15, имя: ['спортивная школа один']
#
# Запись 5
# --> Запрос: академия фигурного катания наши надежды, регион: московская область
# --> Расстояние от второго до первого: 0.8, разность первого и второго: 0.69
# --> Верный id: 110
# --> Варианты модели:
#     --> 110, вероятность 0.87, имя: ['наши надежды']
#     --> 21, вероятность 0.18, имя: ['армия фигурного катания']
#     --> 301, вероятность 0.0, имя: ['центр физической культуры спорта лобня']
#     --> 248, вероятность 0.0, имя: ['центр спортивных технологий']
#     --> 1, вероятность 0.0, имя: ['авангард']
#
# Запись 6 - НЕВЕРНО
# --> Запрос: московская академия фигурного катания на коньках хрустальный, регион: москва
# --> Расстояние от второго до первого: 0.33, разность первого и второго: 0.27
# --> Верный id: 244
# --> Варианты модели:
#     --> 96, вероятность 0.83, имя: ['московская академия фигурного катания на коньках']
#     --> 244, вероятность 0.56, имя: ['хрустальный']
#     --> 10, вероятность 0.44, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.19, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 7
# --> Запрос: ледовый дворец, регион: тульская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 86
# --> Варианты модели:
#     --> 86, вероятность 1.0, имя: ['ледовый дворец']
#     --> 117, вероятность 0.0, имя: ['областная комплексная спортивная школа олимпийского резерва']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 8
# --> Запрос: спортивный клуб армия фигурного катания, регион: москва
# --> Расстояние от второго до первого: 0.61, разность первого и второго: 0.49
# --> Верный id: 20
# --> Варианты модели:
#     --> 20, вероятность 0.81, имя: ['армия фигурного катания']
#     --> 1843, вероятность 0.32, имя: ['клуб фигурного катания герасимовой']
#     --> 251, вероятность 0.31, имя: ['центральный спортивный клуб армии']
#     --> 1845, вероятность 0.26, имя: ['клуб фигурного катания ледяной ангел']
#     --> 293, вероятность 0.2, имя: ['лига фигурного катания']
#
# Запись 9
# --> Запрос: кк спортивная школа олимпийского резерва по фигурного катания на коньках, регион: краснодарский край
# --> Расстояние от второго до первого: 0.57, разность первого и второго: 0.47
# --> Верный id: 199
# --> Варианты модели:
#     --> 199, вероятность 0.82, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#     --> 179, вероятность 0.35, имя: ['спортивная школа по фигурному катанию на коньках хоккею']
#     --> 144, вероятность 0.21, имя: ['региональный центр спортивной подготовки по федерация фигурного катания']
#     --> 158, вероятность 0.0, имя: ['снеговик']
#     --> 13, вероятность 0.0, имя: ['аллигатор']
#
# Запись 10
# --> Запрос: спортивная школа прибой, регион: тюменская область
# --> Расстояние от второго до первого: 0.85, разность первого и второго: 0.78
# --> Верный id: 135
# --> Варианты модели:
#     --> 135, вероятность 0.91, имя: ['прибой']
#     --> 53, вероятность 0.14, имя: ['детско юношеская спортивная школа один']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 11
# --> Запрос: спортивная школа центр зимних видов спорта, регион: новосибирская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.97
# --> Верный id: 249
# --> Варианты модели:
#     --> 249, вероятность 0.97, имя: ['центр зимних видов спорта']
#     --> 23, вероятность 0.0, имя: ['бердск']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 12
# --> Запрос: спортивная школа олимпийского резерва тринадцать волгарь, регион: самарская область
# --> Расстояние от второго до первого: 0.51, разность первого и второго: 0.32
# --> Верный id: 33
# --> Варианты модели:
#     --> 33, вероятность 0.62, имя: ['волгарь']
#     --> 206, вероятность 0.31, имя: ['спортивная школа олимпийского резерва один']
#     --> 54, вероятность 0.07, имя: ['детско юношеская спортивная школа десять']
#     --> 107, вероятность 0.0, имя: ['московская академия фигурного катания на конька']
#     --> None, вероятность 0.0, имя: []
#
# Запись 13
# --> Запрос: академия ледовых видов спорта динамо, регион: санкт петербург
# --> Расстояние от второго до первого: 0.67, разность первого и второго: 0.67
# --> Верный id: 48
# --> Варианты модели:
#     --> 48, вероятность 1.0, имя: ['академия ледовых видов спорта динамо']
#     --> 277, вероятность 0.33, имя: ['клуб фигурного катания динамо']
#     --> 198, вероятность 0.15, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 254, вероятность 0.08, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.08, имя: ['центр физической культуры спорта здоровья московского района']
#
# Запись 14
# --> Запрос: всеволжская спортивная школа олимпийского резерва всеволожский район, регион: ленинградская область
# --> Расстояние от второго до первого: 0.87, разность первого и второго: 0.87
# --> Верный id: 35
# --> Варианты модели:
#     --> 35, вероятность 1.0, имя: ['всеволжская спортивная школа олимпийского резерва']
#     --> 1847, вероятность 0.13, имя: ['спортивная школа богатырь']
#     --> 1848, вероятность 0.09, имя: ['центр подготовки спортивного резерва']
#     --> 1839, вероятность 0.0, имя: ['ледовая арена кириши']
#     --> 1838, вероятность 0.0, имя: ['центр подготовки по фигурному катанию на коньках хоккею глайд']
#
# Запись 15
# --> Запрос: смоленск согбоудо спортивная школа по хоккею шайбой, регион: смоленская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 180
# --> Варианты модели:
#     --> 180, вероятность 1.0, имя: ['спортивная школа по хоккею шайбой']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 16
# --> Запрос: спортивная школа олимпийского резерва один, регион: самарская область
# --> Расстояние от второго до первого: 0.88, разность первого и второго: 0.88
# --> Верный id: 206
# --> Варианты модели:
#     --> 206, вероятность 1.0, имя: ['спортивная школа олимпийского резерва один']
#     --> 54, вероятность 0.12, имя: ['детско юношеская спортивная школа десять']
#     --> 107, вероятность 0.0, имя: ['московская академия фигурного катания на конька']
#     --> 33, вероятность 0.0, имя: ['волгарь']
#     --> None, вероятность 0.0, имя: []
#
# Запись 17
# --> Запрос: спортивная школа центр по ледовым видам спорта, регион: красноярский край
# --> Расстояние от второго до первого: 0.45, разность первого и второго: 0.16
# --> Верный id: 246
# --> Варианты модели:
#     --> 246, вероятность 0.36, имя: ['центр по ледовые виды спорта']
#     --> 174, вероятность 0.2, имя: ['спортивная школа зимние виды спорта']
#     --> 139, вероятность 0.0, имя: ['рассвет']
#     --> 80, вероятность 0.0, имя: ['красноярск']
#     --> None, вероятность 0.0, имя: []
#
# Запись 18
# --> Запрос: центр физической культуры спорта здоровья василеостровского района, регион: санкт петербург
# --> Расстояние от второго до первого: 0.24, разность первого и второго: 0.24
# --> Верный id: 254
# --> Варианты модели:
#     --> 254, вероятность 1.0, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.76, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 253, вероятность 0.76, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 257, вероятность 0.76, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 270, вероятность 0.71, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 19
# --> Запрос: детско юношеская спортивно оздоровительная школа сияние, регион: воронежская область
# --> Расстояние от второго до первого: 0.25, разность первого и второго: 0.13
# --> Верный id: 154
# --> Варианты модели:
#     --> 154, вероятность 0.52, имя: ['сияние']
#     --> 268, вероятность 0.39, имя: ['детско юношеская спортивная школа восточная']
#     --> 1849, вероятность 0.03, имя: ['спортивная школа олимпийского резерва двадцать четыре']
#     --> 245, вероятность 0.0, имя: ['хрустальный конек']
#     --> 146, вероятность 0.0, имя: ['рысь']
#
# Запись 20 - НЕВЕРНО
# --> Запрос: спортивная школа по зимние виды спорта, регион: ставропольский край
# --> Расстояние от второго до первого: 0.07, разность первого и второго: 0.01
# --> Верный id: 191
# --> Варианты модели:
#     --> 163, вероятность 0.12, имя: ['союз мастеров спорта']
#     --> 191, вероятность 0.11, имя: ['спортивная школа невинномысск']
#     --> 167, вероятность 0.0, имя: ['ставрополь арена']
#     --> 242, вероятность 0.0, имя: ['федерация фигурного катания на коньках ставропольского края']
#     --> 236, вероятность 0.0, имя: ['федерация фигурного катания спортивный клуб']
#
# Запись 21
# --> Запрос: спортивная школа два, регион: None
# --> Расстояние от второго до первого: 0.16, разность первого и второго: 0.16
# --> Верный id: 302
# --> Варианты модели:
#     --> 302, вероятность 1.0, имя: ['спортивная школа два']
#     --> 210, вероятность 0.84, имя: ['спортивная школа олимпийского резерва два']
#     --> 211, вероятность 0.84, имя: ['спортивная школа олимпийского резерва два']
#     --> 209, вероятность 0.84, имя: ['спортивная школа олимпийского резерва два']
#     --> 56, вероятность 0.68, имя: ['детско юношеская спортивная школа два']
#
# Запись 22
# --> Запрос: краснодарский крй сочи кк региональный центр спортивной подготовки по фигурного катания на коньках, регион: None
# --> Расстояние от второго до первого: 0.25, разность первого и второго: 0.17
# --> Верный id: 144
# --> Варианты модели:
#     --> 144, вероятность 0.7, имя: ['региональный центр спортивной подготовки по федерация фигурного катания']
#     --> 145, вероятность 0.53, имя: ['региональный центр спортивной подготовки по зимним видам спорта']
#     --> 232, вероятность 0.37, имя: ['фигурного катания на коньках']
#     --> 199, вероятность 0.36, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#     --> 200, вероятность 0.36, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#
# Запись 23
# --> Запрос: спортивная школа олимпийского резерва олимп, регион: калужская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.74
# --> Верный id: 118
# --> Варианты модели:
#     --> 118, вероятность 0.74, имя: ['олимп']
#     --> 78, вероятность 0.0, имя: ['космос']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 24
# --> Запрос: физкультурно спортивное объединение хоккей москвы спортивная школа созвездие, регион: None
# --> Расстояние от второго до первого: 0.0, разность первого и второго: 0.0
# --> Верный id: 160
# --> Варианты модели:
#     --> 160, вероятность 0.58, имя: ['созвездие']
#     --> 159, вероятность 0.58, имя: ['созвездие']
#     --> 279, вероятность 0.43, имя: ['созвездие айс']
#     --> 100, вероятность 0.25, имя: ['спортивная школа']
#     --> 1841, вероятность 0.25, имя: ['спортивная школа']
#
# Запись 25
# --> Запрос: спортивная школа олимпийского резерва академия фигурного катания на коньках, регион: санкт петербург
# --> Расстояние от второго до первого: 0.59, разность первого и второго: 0.59
# --> Верный id: 198
# --> Варианты модели:
#     --> 198, вероятность 1.0, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 220, вероятность 0.41, имя: ['спортивная школа олимпийского резерва один']
#     --> 192, вероятность 0.29, имя: ['спортивная школа олимпийского резерва колпинского района']
#     --> 24, вероятность 0.27, имя: ['школа фигурного катания бережной']
#     --> 208, вероятность 0.26, имя: ['спортивная школа олимпийского резерва один московского района']
#
# Запись 26
# --> Запрос: спортивная школа восемь локомотив, регион: свердловская область
# --> Расстояние от второго до первого: 0.84, разность первого и второго: 0.54
# --> Верный id: 90
# --> Варианты модели:
#     --> 90, вероятность 0.64, имя: ['локомотив']
#     --> 185, вероятность 0.11, имя: ['спортивная школа девятнадцать']
#     --> 72, вероятность 0.07, имя: ['спортивная школа им александра козицына']
#     --> 260, вероятность 0.0, имя: ['энергия']
#     --> 264, вероятность 0.0, имя: ['юность']
#
# Запись 27 - НЕВЕРНО
# --> Запрос: московская академия фигурного катания на коньках легенда, регион: москва
# --> Расстояние от второго до первого: 0.24, разность первого и второго: 0.19
# --> Верный id: 82
# --> Варианты модели:
#     --> 96, вероятность 0.8, имя: ['московская академия фигурного катания на коньках']
#     --> 82, вероятность 0.61, имя: ['легенда']
#     --> 10, вероятность 0.42, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.18, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.17, имя: ['лига фигурного катания']
#
# Запись 28
# --> Запрос: спортивная школа, регион: None
# --> Расстояние от второго до первого: 0.0, разность первого и второго: 0.0
# --> Верный id: 1841
# --> Варианты модели:
#     --> 1841, вероятность 1.0, имя: ['спортивная школа']
#     --> 100, вероятность 1.0, имя: ['спортивная школа']
#     --> 173, вероятность 1.0, имя: ['спортивная школа']
#     --> 182, вероятность 0.54, имя: ['спортивная школа один']
#     --> 183, вероятность 0.54, имя: ['спортивная школа один']
#
# Запись 29
# --> Запрос: спортивная школа олимпийского резерва по ледовым видам спорта нижний новгород, регион: нижегородская область
# --> Расстояние от второго до первого: 0.7, разность первого и второго: 0.22
# --> Верный id: 37
# --> Варианты модели:
#     --> 37, вероятность 0.31, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 183, вероятность 0.1, имя: ['спортивная школа один']
#     --> 45, вероятность 0.09, имя: ['дворец спорта юность']
#     --> 233, вероятность 0.0, имя: ['физкультурно оздоровительный комплекс городец']
#     --> 120, вероятность 0.0, имя: ['олимп']
#
# Запись 30
# --> Запрос: спортивная школа олимпийского резерва шесть, регион: ростовская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 216
# --> Варианты модели:
#     --> 216, вероятность 1.0, имя: ['спортивная школа олимпийского резерва шесть']
#     --> 83, вероятность 0.0, имя: ['ледовая академия']
#     --> 137, вероятность 0.0, имя: ['профессионал']
#     --> 141, вероятность 0.0, имя: ['ростовская областная федерация фигурного катания на коньках']
#     --> None, вероятность 0.0, имя: []
#
# Запись 31
# --> Запрос: спортивная школа олимпийского резерва тодес, регион: челябинская область
# --> Расстояние от второго до первого: 0.83, разность первого и второго: 0.68
# --> Верный id: 224
# --> Варианты модели:
#     --> 224, вероятность 0.81, имя: ['тодес']
#     --> 188, вероятность 0.13, имя: ['спортивная школа семь']
#     --> 261, вероятность 0.0, имя: ['южное сияние']
#     --> 226, вероятность 0.0, имя: ['ужный урал']
#     --> 145, вероятность 0.0, имя: ['региональный центр спортивной подготовки по зимним видам спорта']
#
# Запись 32
# --> Запрос: центр физической культуры московского района, регион: None
# --> Расстояние от второго до первого: 0.31, разность первого и второго: 0.27
# --> Верный id: 256
# --> Варианты модели:
#     --> 256, вероятность 0.88, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 254, вероятность 0.61, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 257, вероятность 0.6, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 253, вероятность 0.6, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 270, вероятность 0.57, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 33
# --> Запрос: физкультурно спортивное золотые надежды, регион: None
# --> Расстояние от второго до первого: 0.55, разность первого и второго: 0.44
# --> Верный id: 64
# --> Варианты модели:
#     --> 64, вероятность 0.8, имя: ['золотые надежды']
#     --> 110, вероятность 0.36, имя: ['наши надежды']
#     --> 233, вероятность 0.16, имя: ['физкультурно оздоровительный комплекс городец']
#     --> 107, вероятность 0.0, имя: ['московская академия фигурного катания на конька']
#     --> 100, вероятность 0.0, имя: ['спортивная школа']
#
# Запись 34
# --> Запрос: спортивная школа олимпийского резерва по ледовые виды спорта им михайлова, регион: тверская область
# --> Расстояние от второго до первого: 0.28, разность первого и второго: 0.25
# --> Верный id: 195
# --> Варианты модели:
#     --> 195, вероятность 0.88, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 193, вероятность 0.63, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#     --> 234, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 232, вероятность 0.0, имя: ['фигурного катания на коньках']
#     --> 41, вероятность 0.0, имя: ['гусева']
#
# Запись 35
# --> Запрос: академия фигурного катания ангелы плющенко, регион: москва
# --> Расстояние от второго до первого: 0.59, разность первого и второго: 0.5
# --> Верный id: 15
# --> Варианты модели:
#     --> 15, вероятность 0.84, имя: ['ангелы плющенко']
#     --> 96, вероятность 0.35, имя: ['московская академия фигурного катания на коньках']
#     --> 10, вероятность 0.22, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.19, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 36
# --> Запрос: спортивная школа олимпийского резерва им ляпкина, регион: московская область
# --> Расстояние от второго до первого: 0.77, разность первого и второго: 0.49
# --> Верный id: 92
# --> Варианты модели:
#     --> 92, вероятность 0.64, имя: ['ляпкина']
#     --> 227, вероятность 0.15, имя: ['училище техникум олимпийского резерва один']
#     --> 301, вероятность 0.0, имя: ['центр физической культуры спорта лобня']
#     --> 248, вероятность 0.0, имя: ['центр спортивных технологий']
#     --> 1, вероятность 0.0, имя: ['авангард']
#
# Запись 37
# --> Запрос: спортивная школа олимпийского резерва один, регион: курганская область
# --> Расстояние от второго до первого: 0.5, разность первого и второго: 0.5
# --> Верный id: 207
# --> Варианты модели:
#     --> 207, вероятность 1.0, имя: ['спортивная школа олимпийского резерва один']
#     --> 210, вероятность 0.5, имя: ['спортивная школа олимпийского резерва два']
#     --> 55, вероятность 0.14, имя: ['детско юношеская спортивная школа два']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 38
# --> Запрос: удмуртской республики ледовый дворец ижсталь, регион: удмуртская республика
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.49
# --> Верный id: 65
# --> Варианты модели:
#     --> 65, вероятность 0.49, имя: ['ижсталь']
#     --> 609, вероятность 0.0, имя: ['спортивная школа гвоздика']
#     --> 228, вероятность 0.0, имя: ['удмуртская федерация фигурного катания']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 39
# --> Запрос: училище техникум олимпийского резерва один, регион: московская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 227
# --> Варианты модели:
#     --> 227, вероятность 1.0, имя: ['училище техникум олимпийского резерва один']
#     --> 301, вероятность 0.0, имя: ['центр физической культуры спорта лобня']
#     --> 248, вероятность 0.0, имя: ['центр спортивных технологий']
#     --> 1, вероятность 0.0, имя: ['авангард']
#     --> 129, вероятность 0.0, имя: ['пахомовой']
#
# Запись 40
# --> Запрос: спортивный клуб армия фигурного катания, регион: московская область
# --> Расстояние от второго до первого: 0.75, разность первого и второго: 0.61
# --> Верный id: 21
# --> Варианты модели:
#     --> 21, вероятность 0.81, имя: ['армия фигурного катания']
#     --> 70, вероятность 0.21, имя: ['клин спортивный']
#     --> 301, вероятность 0.0, имя: ['центр физической культуры спорта лобня']
#     --> 248, вероятность 0.0, имя: ['центр спортивных технологий']
#     --> 1, вероятность 0.0, имя: ['авангард']
#
# Запись 41
# --> Запрос: федерация фигурного катания на коньках, регион: республика карелия
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 237
# --> Варианты модели:
#     --> 237, вероятность 1.0, имя: ['федерация фигурного катания на коньках']
#     --> 190, вероятность 0.0, имя: ['спортивная школа шесть']
#     --> 67, вероятность 0.0, имя: ['керриган']
#     --> 56, вероятность 0.0, имя: ['детско юношеская спортивная школа два']
#     --> None, вероятность 0.0, имя: []
#
# Запись 42
# --> Запрос: спортивная школа дымка, регион: кировская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.92
# --> Верный id: 50
# --> Варианты модели:
#     --> 50, вероятность 0.92, имя: ['дымка']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 43
# --> Запрос: союз фигурного катания беломорец, регион: архангельская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.69
# --> Верный id: 22
# --> Варианты модели:
#     --> 22, вероятность 0.69, имя: ['беломорец']
#     --> 9, вероятность 0.0, имя: ['звездочка']
#     --> 66, вероятность 0.0, имя: ['каскад']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 44
# --> Запрос: омска спортивная школа олимпийского резерва тридцать пять, регион: омская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.83
# --> Верный id: 212
# --> Варианты модели:
#     --> 212, вероятность 0.83, имя: ['спортивная школа олимпийского резерва тридцать пять']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 45 - НЕВЕРНО
# --> Запрос: физкультурно спортивное объединение локомотив, регион: None
# --> Расстояние от второго до первого: 0.0, разность первого и второго: 0.0
# --> Верный id: 89
# --> Варианты модели:
#     --> 90, вероятность 0.55, имя: ['локомотив']
#     --> 89, вероятность 0.55, имя: ['локомотив']
#     --> 233, вероятность 0.18, имя: ['физкультурно оздоровительный комплекс городец']
#     --> 1852, вероятность 0.0, имя: ['ассоль']
#     --> 101, вероятность 0.0, имя: ['медведково']
#
# Запись 46
# --> Запрос: санкт петрбург школа фигурного катания бережной, регион: None
# --> Расстояние от второго до первого: 0.44, разность первого и второго: 0.28
# --> Верный id: 24
# --> Варианты модели:
#     --> 24, вероятность 0.63, имя: ['школа фигурного катания бережной']
#     --> 292, вероятность 0.35, имя: ['школа фигурного катания']
#     --> 178, вероятность 0.25, имя: ['спортивная школа по фигурного катания']
#     --> 235, вероятность 0.2, имя: ['федерация фигурного катания']
#     --> 234, вероятность 0.2, имя: ['федерация фигурного катания']
#
# Запись 47
# --> Запрос: спортивная школа олимпийского резерва олимп, регион: калужская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.74
# --> Верный id: 118
# --> Варианты модели:
#     --> 118, вероятность 0.74, имя: ['олимп']
#     --> 78, вероятность 0.0, имя: ['космос']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 48
# --> Запрос: титул, регион: None
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 223
# --> Варианты модели:
#     --> 223, вероятность 1.0, имя: ['титул']
#     --> 108, вероятность 0.0, имя: ['мотодром арена']
#     --> 100, вероятность 0.0, имя: ['спортивная школа']
#     --> 101, вероятность 0.0, имя: ['медведково']
#     --> 102, вероятность 0.0, имя: ['мечта']
#
# Запись 49
# --> Запрос: центр физкультуры здоровья красногвардейского района, регион: None
# --> Расстояние от второго до первого: 0.38, разность первого и второго: 0.26
# --> Верный id: 253
# --> Варианты модели:
#     --> 253, вероятность 0.68, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 254, вероятность 0.42, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.42, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 257, вероятность 0.41, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 270, вероятность 0.39, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 50
# --> Запрос: спортивная школа центр зимних видов спорта, регион: новосибирская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.97
# --> Верный id: 249
# --> Варианты модели:
#     --> 249, вероятность 0.97, имя: ['центр зимних видов спорта']
#     --> 23, вероятность 0.0, имя: ['бердск']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 51
# --> Запрос: сор им ляпкина, регион: московская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.75
# --> Верный id: 92
# --> Варианты модели:
#     --> 92, вероятность 0.75, имя: ['ляпкина']
#     --> 301, вероятность 0.0, имя: ['центр физической культуры спорта лобня']
#     --> 248, вероятность 0.0, имя: ['центр спортивных технологий']
#     --> 1, вероятность 0.0, имя: ['авангард']
#     --> 227, вероятность 0.0, имя: ['училище техникум олимпийского резерва один']
#
# Запись 52
# --> Запрос: спортивная школа олимпийского резерва звездный лед, регион: санкт петербург
# --> Расстояние от второго до первого: 0.53, разность первого и второго: 0.45
# --> Верный id: 62
# --> Варианты модели:
#     --> 62, вероятность 0.85, имя: ['звездный лед']
#     --> 220, вероятность 0.39, имя: ['спортивная школа олимпийского резерва один']
#     --> 25, вероятность 0.33, имя: ['бриллиантовый лед']
#     --> 111, вероятность 0.33, имя: ['невский лед']
#     --> 198, вероятность 0.3, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#
# Запись 53 - НЕВЕРНО
# --> Запрос: кк спортивная школа по фккик, регион: краснодарский край
# --> Расстояние от второго до первого: 0.28, разность первого и второго: 0.09
# --> Верный id: 179
# --> Варианты модели:
#     --> 199, вероятность 0.33, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#     --> 179, вероятность 0.24, имя: ['спортивная школа по фигурному катанию на коньках хоккею']
#     --> 144, вероятность 0.14, имя: ['региональный центр спортивной подготовки по федерация фигурного катания']
#     --> 158, вероятность 0.0, имя: ['снеговик']
#     --> 13, вероятность 0.0, имя: ['аллигатор']
#
# Запись 54
# --> Запрос: физкультурно спортивное объединение школа фигурного катания буревестник, регион: санкт петербург
# --> Расстояние от второго до первого: 0.63, разность первого и второго: 0.35
# --> Верный id: 27
# --> Варианты модели:
#     --> 27, вероятность 0.55, имя: ['буревестник']
#     --> 24, вероятность 0.2, имя: ['школа фигурного катания бережной']
#     --> 198, вероятность 0.18, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 277, вероятность 0.16, имя: ['клуб фигурного катания динамо']
#     --> 105, вероятность 0.13, имя: ['спортивный клуб фигурного катания москвиной']
#
# Запись 55
# --> Запрос: ледовый дворец, регион: вологодская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 85
# --> Варианты модели:
#     --> 85, вероятность 1.0, имя: ['ледовый дворец']
#     --> 181, вероятность 0.0, имя: ['спортивная школа один']
#     --> 31, вероятность 0.0, имя: ['витязь']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 56
# --> Запрос: спортивная школа олимпийского резерва звездный лед, регион: санкт петербург
# --> Расстояние от второго до первого: 0.53, разность первого и второго: 0.45
# --> Верный id: 62
# --> Варианты модели:
#     --> 62, вероятность 0.85, имя: ['звездный лед']
#     --> 220, вероятность 0.39, имя: ['спортивная школа олимпийского резерва один']
#     --> 25, вероятность 0.33, имя: ['бриллиантовый лед']
#     --> 111, вероятность 0.33, имя: ['невский лед']
#     --> 198, вероятность 0.3, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#
# Запись 57
# --> Запрос: физкультурно спортивное объединение школа фигурного катания бриллиантовый лед, регион: None
# --> Расстояние от второго до первого: 0.51, разность первого и второго: 0.33
# --> Верный id: 25
# --> Варианты модели:
#     --> 25, вероятность 0.66, имя: ['бриллиантовый лед']
#     --> 292, вероятность 0.33, имя: ['школа фигурного катания']
#     --> 62, вероятность 0.26, имя: ['звездный лед']
#     --> 1844, вероятность 0.24, имя: ['спортивная школа алмазный лед']
#     --> 178, вероятность 0.23, имя: ['спортивная школа по фигурного катания']
#
# Запись 58
# --> Запрос: мбоудо иркутск детско юношеская спортивная школа семь, регион: иркутская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 58
# --> Варианты модели:
#     --> 58, вероятность 1.0, имя: ['детско юношеская спортивная школа семь']
#     --> 127, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 60, вероятность 0.0, имя: ['ермак']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 59
# --> Запрос: спортивный клуб фигурного катания москвиной, регион: санкт петербург
# --> Расстояние от второго до первого: 0.6, разность первого и второго: 0.6
# --> Верный id: 105
# --> Варианты модели:
#     --> 105, вероятность 1.0, имя: ['спортивный клуб фигурного катания москвиной']
#     --> 277, вероятность 0.4, имя: ['клуб фигурного катания динамо']
#     --> 272, вероятность 0.4, имя: ['спортивный клуб фигурного катания open ice']
#     --> 286, вероятность 0.4, имя: ['спортивный клуб фигурного катания ice prestige']
#     --> 156, вероятность 0.4, имя: ['хоккейный клуб спортивный клуб армии']
#
# Запись 60 - НЕВЕРНО
# --> Запрос: спортивная школа олимпийского резерва, регион: санкт петербург
# --> Расстояние от второго до первого: 0.25, разность первого и второго: 0.18
# --> Верный id: 198
# --> Варианты модели:
#     --> 220, вероятность 0.74, имя: ['спортивная школа олимпийского резерва один']
#     --> 198, вероятность 0.56, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 192, вероятность 0.51, имя: ['спортивная школа олимпийского резерва колпинского района']
#     --> 208, вероятность 0.47, имя: ['спортивная школа олимпийского резерва один московского района']
#     --> 282, вероятность 0.22, имя: ['спортивная школа олимпийского резерва комплексная филиала российская федерация центральный спортивный клуб армии спортивный клуб армии']
#
# Запись 61 - НЕВЕРНО
# --> Запрос: московская академия фигурного катания на коньках школа мечта, регион: москва
# --> Расстояние от второго до первого: 0.3, разность первого и второго: 0.24
# --> Верный id: 102
# --> Варианты модели:
#     --> 96, вероятность 0.8, имя: ['московская академия фигурного катания на коньках']
#     --> 102, вероятность 0.56, имя: ['мечта']
#     --> 10, вероятность 0.42, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.18, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 62
# --> Запрос: ржевка центр физкультуры здоровья красногвардейского района, регион: None
# --> Расстояние от второго до первого: 0.38, разность первого и второго: 0.22
# --> Верный id: 253
# --> Варианты модели:
#     --> 253, вероятность 0.57, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 254, вероятность 0.35, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.35, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 257, вероятность 0.35, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 270, вероятность 0.33, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 63
# --> Запрос: ледовый дворец, регион: вологодская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 85
# --> Варианты модели:
#     --> 85, вероятность 1.0, имя: ['ледовый дворец']
#     --> 181, вероятность 0.0, имя: ['спортивная школа один']
#     --> 31, вероятность 0.0, имя: ['витязь']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 64
# --> Запрос: клуб фигурного катания звезда, регион: None
# --> Расстояние от второго до первого: 0.33, разность первого и второго: 0.24
# --> Верный id: 61
# --> Варианты модели:
#     --> 61, вероятность 0.73, имя: ['звезда']
#     --> 150, вероятность 0.49, имя: ['северная звезда']
#     --> 277, вероятность 0.47, имя: ['клуб фигурного катания динамо']
#     --> 79, вероятность 0.45, имя: ['красная звезда']
#     --> 611, вероятность 0.45, имя: ['клуб фигурного катания айсберг']
#
# Запись 65
# --> Запрос: центр физической культуры спорта здоровья василеостровского района, регион: санкт петербург
# --> Расстояние от второго до первого: 0.24, разность первого и второго: 0.24
# --> Верный id: 254
# --> Варианты модели:
#     --> 254, вероятность 1.0, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.76, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 253, вероятность 0.76, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 257, вероятность 0.76, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 270, вероятность 0.71, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 66
# --> Запрос: академия фигурного катания ангелы плющенко, регион: москва
# --> Расстояние от второго до первого: 0.59, разность первого и второго: 0.5
# --> Верный id: 15
# --> Варианты модели:
#     --> 15, вероятность 0.84, имя: ['ангелы плющенко']
#     --> 96, вероятность 0.35, имя: ['московская академия фигурного катания на коньках']
#     --> 10, вероятность 0.22, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.19, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 67
# --> Запрос: прометей клуб фигурного катания созвездие айс, регион: None
# --> Расстояние от второго до первого: 0.25, разность первого и второго: 0.21
# --> Верный id: 279
# --> Варианты модели:
#     --> 279, вероятность 0.85, имя: ['созвездие айс']
#     --> 159, вероятность 0.64, имя: ['созвездие']
#     --> 160, вероятность 0.64, имя: ['созвездие']
#     --> 38, вероятность 0.38, имя: ['голден айс']
#     --> 277, вероятность 0.36, имя: ['клуб фигурного катания динамо']
#
# Запись 68
# --> Запрос: югры федерация фигурного катания на коньках, регион: ханты мансийский автономный округ
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 238
# --> Варианты модели:
#     --> 238, вероятность 1.0, имя: ['федерация фигурного катания на коньках']
#     --> 265, вероятность 0.0, имя: ['юность']
#     --> 173, вероятность 0.0, имя: ['спортивная школа']
#     --> 123, вероятность 0.0, имя: ['олимпиец']
#     --> 87, вероятность 0.0, имя: ['ледовый дворец спорта']
#
# Запись 69
# --> Запрос: спортивная школа спорт индустрия, регион: новгородская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.95
# --> Верный id: 166
# --> Варианты модели:
#     --> 166, вероятность 0.95, имя: ['спорт индустрия']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 70
# --> Запрос: спортивная школа кристалл, регион: сахалинская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.93
# --> Верный id: 81
# --> Варианты модели:
#     --> 81, вероятность 0.93, имя: ['кристалл']
#     --> 243, вероятность 0.0, имя: ['холмск арена']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 71
# --> Запрос: первоуральское физической культуры спорта старт, регион: свердловская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.47
# --> Верный id: 169
# --> Варианты модели:
#     --> 169, вероятность 0.47, имя: ['старт']
#     --> 260, вероятность 0.0, имя: ['энергия']
#     --> 264, вероятность 0.0, имя: ['юность']
#     --> 185, вероятность 0.0, имя: ['спортивная школа девятнадцать']
#     --> 126, вероятность 0.0, имя: ['олимпия']
#
# Запись 72
# --> Запрос: голден айс петергоф спортивная школа манеж, регион: None
# --> Расстояние от второго до первого: 0.39, разность первого и второго: 0.39
# --> Верный id: 274
# --> Варианты модели:
#     --> 274, вероятность 1.0, имя: ['голден айс петергоф спортивная школа манеж']
#     --> 38, вероятность 0.61, имя: ['голден айс']
#     --> 279, вероятность 0.28, имя: ['созвездие айс']
#     --> 30, вероятность 0.26, имя: ['вилеса айс']
#     --> 100, вероятность 0.21, имя: ['спортивная школа']
#
# Запись 73
# --> Запрос: клуб фигурного катания айсберг пермь, регион: None
# --> Расстояние от второго до первого: 0.25, разность первого и второго: 0.19
# --> Верный id: 611
# --> Варианты модели:
#     --> 611, вероятность 0.76, имя: ['клуб фигурного катания айсберг']
#     --> 7, вероятность 0.57, имя: ['айсберг']
#     --> 6, вероятность 0.57, имя: ['айсберг']
#     --> 8, вероятность 0.57, имя: ['айсберг']
#     --> 277, вероятность 0.35, имя: ['клуб фигурного катания динамо']
#
# Запись 74
# --> Запрос: спортивная школа десять, регион: самарская область
# --> Расстояние от второго до первого: 0.78, разность первого и второго: 0.58
# --> Верный id: 54
# --> Варианты модели:
#     --> 54, вероятность 0.74, имя: ['детско юношеская спортивная школа десять']
#     --> 206, вероятность 0.17, имя: ['спортивная школа олимпийского резерва один']
#     --> 107, вероятность 0.0, имя: ['московская академия фигурного катания на конька']
#     --> 33, вероятность 0.0, имя: ['волгарь']
#     --> None, вероятность 0.0, имя: []
#
# Запись 75
# --> Запрос: спортивная школа олимпийского резерва колпинского района, регион: санкт петербург
# --> Расстояние от второго до первого: 0.5, разность первого и второго: 0.5
# --> Верный id: 192
# --> Варианты модели:
#     --> 192, вероятность 1.0, имя: ['спортивная школа олимпийского резерва колпинского района']
#     --> 208, вероятность 0.5, имя: ['спортивная школа олимпийского резерва один московского района']
#     --> 220, вероятность 0.38, имя: ['спортивная школа олимпийского резерва один']
#     --> 198, вероятность 0.29, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 254, вероятность 0.21, имя: ['центр физической культуры спорта здоровья василеостровского района']
#
# Запись 76 - НЕВЕРНО
# --> Запрос: академия фигурного катания на коньках отд хрустальный, регион: москва
# --> Расстояние от второго до первого: 0.1, разность первого и второго: 0.05
# --> Верный id: 244
# --> Варианты модели:
#     --> 96, вероятность 0.53, имя: ['московская академия фигурного катания на коньках']
#     --> 244, вероятность 0.48, имя: ['хрустальный']
#     --> 10, вероятность 0.37, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.16, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.16, имя: ['лига фигурного катания']
#
# Запись 77
# --> Запрос: спортивный клуб фигурного катания на коньках ледовая академия, регион: ростовская область
# --> Расстояние от второго до первого: 0.62, разность первого и второго: 0.42
# --> Верный id: 83
# --> Варианты модели:
#     --> 83, вероятность 0.68, имя: ['ледовая академия']
#     --> 141, вероятность 0.26, имя: ['ростовская областная федерация фигурного катания на коньках']
#     --> 216, вероятность 0.0, имя: ['спортивная школа олимпийского резерва шесть']
#     --> 137, вероятность 0.0, имя: ['профессионал']
#     --> None, вероятность 0.0, имя: []
#
# Запись 78
# --> Запрос: вологодская обдасть василеостровского района спортивная школа олимпийского резерва витязь великий устюг, регион: None
# --> Расстояние от второго до первого: 0.29, разность первого и второго: 0.18
# --> Верный id: 31
# --> Варианты модели:
#     --> 31, вероятность 0.62, имя: ['витязь']
#     --> 192, вероятность 0.44, имя: ['спортивная школа олимпийского резерва колпинского района']
#     --> 254, вероятность 0.42, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 208, вероятность 0.4, имя: ['спортивная школа олимпийского резерва один московского района']
#     --> 204, вероятность 0.3, имя: ['спортивная школа олимпийского резерва один']
#
# Запись 79
# --> Запрос: центр физической культуры спорта здоровья фрунзенского на, регион: None
# --> Расстояние от второго до первого: 0.29, разность первого и второго: 0.26
# --> Верный id: 257
# --> Варианты модели:
#     --> 257, вероятность 0.88, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 254, вероятность 0.63, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.62, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 253, вероятность 0.62, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 270, вероятность 0.59, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 80
# --> Запрос: спортивная школа прибой, регион: тюменская область
# --> Расстояние от второго до первого: 0.85, разность первого и второго: 0.78
# --> Верный id: 135
# --> Варианты модели:
#     --> 135, вероятность 0.91, имя: ['прибой']
#     --> 53, вероятность 0.14, имя: ['детско юношеская спортивная школа один']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 81
# --> Запрос: центр физической культуры здоровья фрунзенского на, регион: санкт петербург
# --> Расстояние от второго до первого: 0.32, разность первого и второго: 0.27
# --> Верный id: 257
# --> Варианты модели:
#     --> 257, вероятность 0.84, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 254, вероятность 0.57, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.57, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 253, вероятность 0.57, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 270, вероятность 0.54, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 82 - НЕВЕРНО
# --> Запрос: спортивная школа по фких, регион: краснодарский край
# --> Расстояние от второго до первого: 0.28, разность первого и второго: 0.15
# --> Верный id: 179
# --> Варианты модели:
#     --> 199, вероятность 0.54, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#     --> 179, вероятность 0.39, имя: ['спортивная школа по фигурному катанию на коньках хоккею']
#     --> 144, вероятность 0.23, имя: ['региональный центр спортивной подготовки по федерация фигурного катания']
#     --> 158, вероятность 0.0, имя: ['снеговик']
#     --> 13, вероятность 0.0, имя: ['аллигатор']
#
# Запись 83 - НЕВЕРНО
# --> Запрос: спортивная школа олимпийского резерва по фигурному катанию на коньках, регион: санкт петербург
# --> Расстояние от второго до первого: 0.21, разность первого и второго: 0.13
# --> Верный id: 198
# --> Варианты модели:
#     --> 250, вероятность 0.62, имя: ['центр олимпийской подготовки по фигурному катанию на коньках']
#     --> 198, вероятность 0.48, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 220, вероятность 0.33, имя: ['спортивная школа олимпийского резерва один']
#     --> 192, вероятность 0.23, имя: ['спортивная школа олимпийского резерва колпинского района']
#     --> 208, вероятность 0.21, имя: ['спортивная школа олимпийского резерва один московского района']
#
# Запись 84
# --> Запрос: республика республики саха спортивная школа по зимние виды спорта, регион: None
# --> Расстояние от второго до первого: 0.2, разность первого и второго: 0.15
# --> Верный id: 142
# --> Варианты модели:
#     --> 142, вероятность 0.77, имя: ['республики саха якутия спортивная школа по зимние виды спорта']
#     --> 176, вероятность 0.62, имя: ['спортивная школа по зимние виды спорта']
#     --> 304, вероятность 0.62, имя: ['спортивная школа по зимние виды спорта']
#     --> 71, вероятность 0.62, имя: ['спортивная школа по зимние виды спорта']
#     --> 193, вероятность 0.57, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#
# Запись 85
# --> Запрос: оренбург спортивная школа олимпийского резерва один, регион: оренбургская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.67
# --> Верный id: 203
# --> Варианты модели:
#     --> 203, вероятность 0.67, имя: ['спортивная школа олимпийского резерва один']
#     --> 121, вероятность 0.0, имя: ['олимп']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 86
# --> Запрос: южно сахалинск спортивная школа кристалл, регион: сахалинская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.93
# --> Верный id: 81
# --> Варианты модели:
#     --> 81, вероятность 0.93, имя: ['кристалл']
#     --> 243, вероятность 0.0, имя: ['холмск арена']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 87
# --> Запрос: мбау всеволжская спортивная школа олимпийского резерва, регион: ленинградская область
# --> Расстояние от второго до первого: 0.87, разность первого и второго: 0.87
# --> Верный id: 35
# --> Варианты модели:
# ...
#     --> 1, вероятность 0.0, имя: ['авангард']
#     --> 227, вероятность 0.0, имя: ['училище техникум олимпийского резерва один']
#
# Запись 152
# --> Запрос: академия ледовые виды спорта динамо, регион: санкт петербург
# --> Расстояние от второго до первого: 0.18, разность первого и второго: 0.09
# --> Верный id: 48
# --> Варианты модели:
#     --> 48, вероятность 0.47, имя: ['академия ледовых видов спорта динамо']
#     --> 277, вероятность 0.38, имя: ['клуб фигурного катания динамо']
#     --> 198, вероятность 0.17, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#     --> 254, вероятность 0.09, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.09, имя: ['центр физической культуры спорта здоровья московского района']
#
# Запись 153
# --> Запрос: школа фигурного катания елены бережной, регион: None
# --> Расстояние от второго до первого: 0.44, разность первого и второго: 0.32
# --> Верный id: 24
# --> Варианты модели:
#     --> 24, вероятность 0.72, имя: ['школа фигурного катания бережной']
#     --> 292, вероятность 0.4, имя: ['школа фигурного катания']
#     --> 178, вероятность 0.29, имя: ['спортивная школа по фигурного катания']
#     --> 235, вероятность 0.23, имя: ['федерация фигурного катания']
#     --> 234, вероятность 0.23, имя: ['федерация фигурного катания']
#
# Запись 154
# --> Запрос: конаковский лед, регион: тверская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 74
# --> Варианты модели:
#     --> 74, вероятность 1.0, имя: ['конаковский лед']
#     --> 195, вероятность 0.0, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 193, вероятность 0.0, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#     --> 234, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 232, вероятность 0.0, имя: ['фигурного катания на коньках']
#
# Запись 155
# --> Запрос: спортивная школа ямал, регион: ямало ненецкий автономный округ
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.92
# --> Верный id: 267
# --> Варианты модели:
#     --> 267, вероятность 0.92, имя: ['ямал']
#     --> 114, вероятность 0.0, имя: ['новый уренгой']
#     --> 240, вероятность 0.0, имя: ['федерация фигурного катания на коньках']
#     --> 19, вероятность 0.0, имя: ['арктур']
#     --> 2, вероятность 0.0, имя: ['авангард']
#
# Запись 156
# --> Запрос: федерация фигурного катания уфа, регион: республика башкортостан
# --> Расстояние от второго до первого: 0.42, разность первого и второго: 0.26
# --> Верный id: 235
# --> Варианты модели:
#     --> 235, вероятность 0.61, имя: ['федерация фигурного катания']
#     --> 292, вероятность 0.35, имя: ['школа фигурного катания']
#     --> 302, вероятность 0.0, имя: ['спортивная школа два']
#     --> 205, вероятность 0.0, имя: ['спортивная школа олимпийского резерва один']
#     --> 147, вероятность 0.0, имя: ['салаватинвест']
#
# Запись 157
# --> Запрос: спортивная школа им гусева, регион: тверская область
# --> Расстояние от второго до первого: 0.88, разность первого и второго: 0.67
# --> Верный id: 41
# --> Варианты модели:
#     --> 41, вероятность 0.75, имя: ['гусева']
#     --> 193, вероятность 0.09, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#     --> 195, вероятность 0.09, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 234, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 232, вероятность 0.0, имя: ['фигурного катания на коньках']
#
# Запись 158
# --> Запрос: спортивная школа олимпийского резерва физкультурно спортивное объединение авиатор, регион: республика татарстан
# --> Расстояние от второго до первого: 0.55, разность первого и второго: 0.31
# --> Верный id: 3
# --> Варианты модели:
#     --> 3, вероятность 0.57, имя: ['авиатор']
#     --> 143, вероятность 0.26, имя: ['республиканская спортивная школа олимпийского резерва']
#     --> 201, вероятность 0.14, имя: ['спортивная школа олимпийского резерва по фигурному катанию на коньках шорт треку']
#     --> 130, вероятность 0.0, имя: ['поволжский государственный университет физической культуры спорта туризма']
#     --> 258, вероятность 0.0, имя: ['челны']
#
# Запись 159
# --> Запрос: первоуральское физической культуры спорта старт, регион: свердловская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.47
# --> Верный id: 169
# --> Варианты модели:
#     --> 169, вероятность 0.47, имя: ['старт']
#     --> 260, вероятность 0.0, имя: ['энергия']
#     --> 264, вероятность 0.0, имя: ['юность']
#     --> 185, вероятность 0.0, имя: ['спортивная школа девятнадцать']
#     --> 126, вероятность 0.0, имя: ['олимпия']
#
# Запись 160
# --> Запрос: титул, регион: None
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 223
# --> Варианты модели:
#     --> 223, вероятность 1.0, имя: ['титул']
#     --> 108, вероятность 0.0, имя: ['мотодром арена']
#     --> 100, вероятность 0.0, имя: ['спортивная школа']
#     --> 101, вероятность 0.0, имя: ['медведково']
#     --> 102, вероятность 0.0, имя: ['мечта']
#
# Запись 161
# --> Запрос: спортивная школа восемь локомотив, регион: свердловская область
# --> Расстояние от второго до первого: 0.84, разность первого и второго: 0.54
# --> Верный id: 90
# --> Варианты модели:
#     --> 90, вероятность 0.64, имя: ['локомотив']
#     --> 185, вероятность 0.11, имя: ['спортивная школа девятнадцать']
#     --> 72, вероятность 0.07, имя: ['спортивная школа им александра козицына']
#     --> 260, вероятность 0.0, имя: ['энергия']
#     --> 264, вероятность 0.0, имя: ['юность']
#
# Запись 162
# --> Запрос: спортивная школа олимпийского резерва два москомспорта, регион: москва
# --> Расстояние от второго до первого: 0.88, разность первого и второго: 0.88
# --> Верный id: 211
# --> Варианты модели:
#     --> 211, вероятность 1.0, имя: ['спортивная школа олимпийского резерва два']
#     --> 1844, вероятность 0.12, имя: ['спортивная школа алмазный лед']
#     --> 1845, вероятность 0.0, имя: ['клуб фигурного катания ледяной ангел']
#     --> 106, вероятность 0.0, имя: ['москвич']
#     --> 10, вероятность 0.0, имя: ['академия синхронного катания на коньках']
#
# Запись 163
# --> Запрос: клуб фигурного катания движение, регион: республика татарстан
# --> Расстояние от второго до первого: 0.87, разность первого и второго: 0.72
# --> Верный id: 43
# --> Варианты модели:
#     --> 43, вероятность 0.83, имя: ['движение']
#     --> 230, вероятность 0.11, имя: ['российская федерация центральный спортивный клуб армии']
#     --> 3, вероятность 0.0, имя: ['авиатор']
#     --> 130, вероятность 0.0, имя: ['поволжский государственный университет физической культуры спорта туризма']
#     --> 258, вероятность 0.0, имя: ['челны']
#
# Запись 164 - НЕВЕРНО
# --> Запрос: спортивный клуб по хоккею шайбой фигурному катанию красная звезда, регион: None
# --> Расстояние от второго до первого: 0.05, разность первого и второго: 0.03
# --> Верный id: 79
# --> Варианты модели:
#     --> 180, вероятность 0.6, имя: ['спортивная школа по хоккею шайбой']
#     --> 179, вероятность 0.56, имя: ['спортивная школа по фигурному катанию на коньках хоккею']
#     --> 79, вероятность 0.55, имя: ['красная звезда']
#     --> 1838, вероятность 0.45, имя: ['центр подготовки по фигурному катанию на коньках хоккею глайд']
#     --> 61, вероятность 0.34, имя: ['звезда']
#
# Запись 165
# --> Запрос: ермак ангарска, регион: иркутская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 60
# --> Варианты модели:
#     --> 60, вероятность 1.0, имя: ['ермак']
#     --> 127, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 58, вероятность 0.0, имя: ['детско юношеская спортивная школа семь']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 166
# --> Запрос: спортивная школа олимпийского резерва тодес челябинска, регион: None
# --> Расстояние от второго до первого: 0.47, разность первого и второго: 0.28
# --> Верный id: 224
# --> Варианты модели:
#     --> 224, вероятность 0.59, имя: ['тодес']
#     --> 1842, вероятность 0.32, имя: ['спортивная школа олимпийского резерва один']
#     --> 219, вероятность 0.32, имя: ['спортивная школа олимпийского резерва один']
#     --> 207, вероятность 0.32, имя: ['спортивная школа олимпийского резерва один']
#     --> 206, вероятность 0.32, имя: ['спортивная школа олимпийского резерва один']
#
# Запись 167
# --> Запрос: академия фигурного катания ангелы плющенко, регион: москва
# --> Расстояние от второго до первого: 0.59, разность первого и второго: 0.5
# --> Верный id: 15
# --> Варианты модели:
#     --> 15, вероятность 0.84, имя: ['ангелы плющенко']
#     --> 96, вероятность 0.35, имя: ['московская академия фигурного катания на коньках']
#     --> 10, вероятность 0.22, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.19, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.18, имя: ['лига фигурного катания']
#
# Запись 168 - НЕВЕРНО
# --> Запрос: спортивная школа олимпийского резерва по ледовым видам спорта, регион: None
# --> Расстояние от второго до первого: 0.01, разность первого и второго: 0.0
# --> Верный id: 195
# --> Варианты модели:
#     --> 193, вероятность 0.41, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#     --> 195, вероятность 0.41, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 37, вероятность 0.41, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 145, вероятность 0.37, имя: ['региональный центр спортивной подготовки по зимним видам спорта']
#     --> 199, вероятность 0.36, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#
# Запись 169
# --> Запрос: центр спортивных технологий, регион: московская область
# --> Расстояние от второго до первого: 0.87, разность первого и второго: 0.87
# --> Верный id: 248
# --> Варианты модели:
#     --> 248, вероятность 1.0, имя: ['центр спортивных технологий']
#     --> 301, вероятность 0.13, имя: ['центр физической культуры спорта лобня']
#     --> 1, вероятность 0.0, имя: ['авангард']
#     --> 227, вероятность 0.0, имя: ['училище техникум олимпийского резерва один']
#     --> 129, вероятность 0.0, имя: ['пахомовой']
#
# Запись 170
# --> Запрос: ooo династия, регион: None
# --> Расстояние от второго до первого: 0.39, разность первого и второго: 0.39
# --> Верный id: 49
# --> Варианты модели:
#     --> 49, вероятность 1.0, имя: ['династия']
#     --> 1837, вероятность 0.61, имя: ['центр развития фигурного катания династия']
#     --> 98, вероятность 0.0, имя: ['спортивная школа один']
#     --> 101, вероятность 0.0, имя: ['медведково']
#     --> 102, вероятность 0.0, имя: ['мечта']
#
# Запись 171
# --> Запрос: областная комплексная спортивная школа олимпийского резерва, регион: тульская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 1.0
# --> Верный id: 117
# --> Варианты модели:
#     --> 117, вероятность 1.0, имя: ['областная комплексная спортивная школа олимпийского резерва']
#     --> 86, вероятность 0.0, имя: ['ледовый дворец']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 172
# --> Запрос: спортивная школа олимпийского резерва звездный лед, регион: санкт петербург
# --> Расстояние от второго до первого: 0.53, разность первого и второго: 0.45
# --> Верный id: 62
# --> Варианты модели:
#     --> 62, вероятность 0.85, имя: ['звездный лед']
#     --> 220, вероятность 0.39, имя: ['спортивная школа олимпийского резерва один']
#     --> 25, вероятность 0.33, имя: ['бриллиантовый лед']
#     --> 111, вероятность 0.33, имя: ['невский лед']
#     --> 198, вероятность 0.3, имя: ['спортивная школа олимпийского резерва академия фигурного катания на коньках']
#
# Запись 173
# --> Запрос: спортивная школа прибой, регион: тюменская область
# --> Расстояние от второго до первого: 0.85, разность первого и второго: 0.78
# --> Верный id: 135
# --> Варианты модели:
#     --> 135, вероятность 0.91, имя: ['прибой']
#     --> 53, вероятность 0.14, имя: ['детско юношеская спортивная школа один']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 174
# --> Запрос: кк региональный центр спортивной подготовки по фигурного катания на коньках сочи, регион: краснодарский край
# --> Расстояние от второго до первого: 0.49, разность первого и второго: 0.35
# --> Верный id: 144
# --> Варианты модели:
#     --> 144, вероятность 0.7, имя: ['региональный центр спортивной подготовки по федерация фигурного катания']
#     --> 199, вероятность 0.36, имя: ['спортивная школа олимпийского резерва по фигурного катания на коньках']
#     --> 179, вероятность 0.18, имя: ['спортивная школа по фигурному катанию на коньках хоккею']
#     --> 158, вероятность 0.0, имя: ['снеговик']
#     --> 13, вероятность 0.0, имя: ['аллигатор']
#
# Запись 175
# --> Запрос: спортивная школа по зимним видам спорта, регион: пензенская область
# --> Расстояние от второго до первого: 0.59, разность первого и второго: 0.19
# --> Верный id: 304
# --> Варианты модели:
#     --> 304, вероятность 0.33, имя: ['спортивная школа по зимние виды спорта']
#     --> 182, вероятность 0.13, имя: ['спортивная школа один']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 176
# --> Запрос: спортивная школа бердск, регион: новосибирская область
# --> Расстояние от второго до первого: 1.0, разность первого и второго: 0.94
# --> Верный id: 23
# --> Варианты модели:
#     --> 23, вероятность 0.94, имя: ['бердск']
#     --> 249, вероятность 0.0, имя: ['центр зимних видов спорта']
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#     --> None, вероятность 0.0, имя: []
#
# Запись 177 - НЕВЕРНО
# --> Запрос: гагаринское центр физической культуры спорта здоровья московский район, регион: None
# --> Расстояние от второго до первого: 0.01, разность первого и второго: 0.0
# --> Верный id: 256
# --> Варианты модели:
#     --> 254, вероятность 0.61, имя: ['центр физической культуры спорта здоровья василеостровского района']
#     --> 256, вероятность 0.61, имя: ['центр физической культуры спорта здоровья московского района']
#     --> 253, вероятность 0.6, имя: ['центр физической культуры спорта здоровья красногвардейского района']
#     --> 257, вероятность 0.6, имя: ['центр физической культуры спорта здоровья фрунзенского района']
#     --> 270, вероятность 0.57, имя: ['центр физической культуры спорта здоровья невского района']
#
# Запись 178
# --> Запрос: детско юношеская спортивная школа им гусева, регион: тверская область
# --> Расстояние от второго до первого: 0.88, разность первого и второго: 0.54
# --> Верный id: 41
# --> Варианты модели:
#     --> 41, вероятность 0.61, имя: ['гусева']
#     --> 193, вероятность 0.07, имя: ['спортивная школа олимпийского резерва по зимние виды спорта']
#     --> 195, вероятность 0.07, имя: ['спортивная школа олимпийского резерва по ледовые виды спорта']
#     --> 234, вероятность 0.0, имя: ['федерация фигурного катания']
#     --> 232, вероятность 0.0, имя: ['фигурного катания на коньках']
#
# Запись 179
# --> Запрос: спортивная школа юность, регион: свердловская область
# --> Расстояние от второго до первого: 0.83, разность первого и второго: 0.74
# --> Верный id: 264
# --> Варианты модели:
#     --> 264, вероятность 0.89, имя: ['юность']
#     --> 185, вероятность 0.15, имя: ['спортивная школа девятнадцать']
#     --> 72, вероятность 0.11, имя: ['спортивная школа им александра козицына']
#     --> 260, вероятность 0.0, имя: ['энергия']
#     --> 169, вероятность 0.0, имя: ['старт']
#
# Запись 180
# --> Запрос: московская академия фигурного катания на коньках школа конек чайковской, регион: москва
# --> Расстояние от второго до первого: 0.17, разность первого и второго: 0.13
# --> Верный id: 75
# --> Варианты модели:
#     --> 75, вероятность 0.76, имя: ['конек чайковской']
#     --> 96, вероятность 0.63, имя: ['московская академия фигурного катания на коньках']
#     --> 10, вероятность 0.33, имя: ['академия синхронного катания на коньках']
#     --> 20, вероятность 0.14, имя: ['армия фигурного катания']
#     --> 293, вероятность 0.14, имя: ['лига фигурного катания']

# %%
# Построение графика
plt.figure(figsize=(8, 5))

# plt.subplot(1, 2, 1)
plt.plot(
    threshold_values, auto_error_rate_values, label="Ошибка автоматического разбора"
)
plt.plot(
    threshold_values,
    manual_processing_rate_values,
    label="Доля ручного разбора",
)
plt.plot(threshold_values, general_error_values, label="Общая ошибка")
plt.xlabel("Порог срабатывания")
plt.ylabel("Доля")
plt.title("Зависимости ошибки и ручного разбора данных")
plt.legend()

plt.show()
